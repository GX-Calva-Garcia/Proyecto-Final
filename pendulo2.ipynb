# %% [markdown]
# # Péndulo de Foucault

# %% [markdown]
# ### 1. Sistema de Referencia No Inerciales

# %% [markdown]
# ### Transformación de coordenadas

# %% [markdown]
# La primera Ley de Newton define un Sistema Inercial (SI) y la segunda Ley de Newton $\vec{F} = \frac{d^2\vec{p}}{dt^2}$ es válida para un SI. Las ecuaciones de movimiento de una particula son las mismas para un SI que para todo aquel sistema de referencia que se mueve con velocidad respecto a éste. Si la regla de transformación entre los dos sistemas es la de Galileo,
#
# $$\vec{r} = \vec{r}' + \vec{u}t$$
#
# $$t = t'$$
#
# la segunda Ley de Newton es invariante ante esta transformación, esto es,
#
# $$\vec{F} = m \frac{d^2 \vec{r}}{dt^2} = m \frac{d^2 \vec{r'}}{dt^2}$$
#
# y ambos sistemas son SI y por tanto miden la misma aceleeración. Esto ya no es valido cuando el segundo sistema ya no se mueve con velocidad constante con respecto al primero.

# %% [markdown]
# Cuando el sistema no es un SI, la seguunda Ley de Newton debe modificarse. Consideremos un sistema inercial de referencia S y un sistema S' que se mueve con respecto al primero, el segundo sistema puede acelerarse y rotar (SNI).
# Sea $\vec{r}(t)$ la posición de una partícula medida desde S (SI) al tiempo $t$, y $\vec{r}'(t)$ la posición de la misma partícula medida desde S' al mismo tiempo t (restringido al caso clásico donde $\Delta t = \Delta t'$). Entonces ambas posiciones estan relacionadas por
#
# $$\vec{r}(t) = \vec{R}(t) + \vec{r'}(t)$$
#
# donde $\vec{R}(t)$ corresponde al vector de posición del origen S' medido desde el sistema S, de tal forma que la primera derivada es
#
# $$\dot{\vec{r}} = \dot{\vec{R}} + \dot{\vec{r'}}$$
#
# descomponiendo al vector $\vec{r}$
#
# $$\dot{\vec{r'}} = x'\hat{i'} + y' \hat{j'} + z' \hat{k'}$$
#
# donde $\hat{i'}$, $\hat{j'}$, $\hat{k'}$ son los vectores unitarios en las direcciones $x'$, $y'$, $z'$ respectivamente, del sistema S'. De esta forma obtenemos que
#
# $$\dot{\vec{r}} = \dot{\vec{R}} + \dot{x}'\hat{i'} + \dot{y}' \hat{j'} + \dot{z}' \hat{k'} + x'\frac{d \hat{i'}}{dt} + y' \frac{d\hat{j'}}{dt} + z' \frac{d\hat{k'}}{dt}$$

# %% [markdown]
# Definimos $\{\dot{\vec{r'}}\}_{SNI} := \dot{x}'\hat{i'} + \dot{y}' \hat{j'} + \dot{z}' \hat{k'}$ que es la velocidad de la partícula medida desde S', entonces la expresión anterior la podemos reescribir como
#
# $$\dot{\vec{r}} = \dot{\vec{R}} + \left\{ \dot{\vec{r'}} \right\}_{SNI}+ x'\frac{d \hat{i'}}{dt} + y' \frac{d\hat{j'}}{dt} + z' \frac{d\hat{k'}}{dt}$$
#
# los terminos restantes corresponden a la rotación del sistema S'.

# %% [markdown]
# Cualquier rotación esta identificada por el vector de velocidad angular $\vec{\omega}$. Las derivadas con respecto al tiempo de los vectores base pueden ser calculados de la siguiente manera: escrinimos la velocidad angular como
#
# $$\vec{\omega} = \omega \hat{n}$$
#
# donde $\hat{n}$ es el eje instantáneo de giro, entonces debido a que $\hat{n}$ es unitario , en una primera aproximación obtenemos para $\Delta \hat{i'}$
#
# $$|\Delta\hat{i'}| = \Delta\theta \sin{\alpha}$$
#
# y el valor absoluto de la derivada temporal es:
#
# $$|\frac{d\hat{i'}}{dt}| = \omega\sin{\alpha}$$
#
# $$\omega = \frac{d\theta}{dt}$$
#
# observamos que la dirección de este vector tiene que ser tanto perpendicular a $\hat{i'}$ como a $\vec{\omega}$, entonces utilizando la definición de producto vectorial podemos escribir que
#
# $$\frac{d\hat{i'}}{dt} = \vec{\omega} \times \hat{i'}$$
#
# Análogamente para los otros vectores unitarios, obtenemos
#
# $$\frac{d\hat{j'}}{dt} = \vec{\omega} \times \hat{j'}$$
#
# $$\frac{d\hat{k'}}{dt} = \vec{\omega} \times \hat{k'}$$
#
# Finalmente podemos reescribir la ecuación que relaciona a S y S' como
#
# $$\dot{\vec{r}} = \dot{\vec{R}} + \left\{ \dot{\vec{r'}} \right\}_{SNI} + \vec{\omega} \times \vec{r'}$$

# %% [markdown]
# Observamos que hay un operador que asociado a la derivada temporal en el SNI, que es
#
# $$\frac{d}{dt} = \left\{\frac{d}{dt}\right\}_{SNI} + \vec{\omega} \times$$
#
# Aplicando dos veces este operador ahora se puede obtener la aceleración
#
# $$\frac{d}{dt} \left( \dot{\vec{r}} - \dot{\vec{R}} \right) = \left[ \left\{\frac{d}{dt}\right\}_{SNI} + \vec{\omega} \times \right] \left[ \left\{\frac{d}{dt}\right\}_{SNI} + \vec{\omega} \times \right] \vec{r'}$$

# %% [markdown]
# simplificando
#
# $$\ddot{\vec{r}} - \ddot{\vec{R}} = \left\{ \frac{d^2 \vec{r'}}{dt^2} \right\}_{SNI} + 2\vec{\omega} \times \left\{\frac{d\vec{r'}}{dt}\right\}_{SNI} + \left\{ \frac{d\vec{\omega}}{dt}\right\}_{SNI} \times \vec{r'} + \vec{\omega} \times (\vec{\omega} \times \vec{r'})$$

# %% [markdown]
# si definimos  $\vec{A} := \vec{\ddot{R}}$ que es la aceleración lineal del sistema S' medida desde S, entonces reescribimos
#
# $$\ddot{\vec{r}} = \vec{A} + \{ \ddot{\vec{r}} \}_{SNI} + 2\vec{\omega} \times \{ \dot{\vec{r'}} \}_{SNI} + \{\dot{\vec{\omega}} \}_{SNI} \times \vec{r'} + \vec{\omega} \times (\vec{\omega} \times \vec{r'})$$

# %% [markdown]
# Ahora podemos escribir la segunda Ley de Newton para sistemas no inerciales
#
# $$\vec{F} = m\vec{A} + m\{ \ddot{\vec{r}} \}_{SNI} + 2m\vec{\omega} \times \{ \dot{\vec{r'}} \}_{SNI} + m\{\dot{\vec{\omega}} \}_{SNI} \times \vec{r'} + m\vec{\omega} \times (\vec{\omega} \times \vec{r'})$$
#
# o equivalentemente
#
# $$m\{ \ddot{\vec{r}} \}_{SNI} = \vec{F} - m\vec{A} - 2m\vec{\omega} \times \{ \dot{\vec{r'}} \}_{SNI} - m\{\dot{\vec{\omega}} \}_{SNI} \times \vec{r'} - m\vec{\omega} \times (\vec{\omega} \times \vec{r'})$$

# %% [markdown]
# Observamos que la ecuación de movimiento para el sistema no inercial se modifica; a la fuerza aplicada $\vec{F}$ deben añadirse terminos no inerciales:
#
# - $-m\vec{A}$ es la fuerza inercial debida a la aceleración $\left(\ddot{\vec{R}}\right)$ del sistema en movimiento.
# - $-2m\vec{\omega} \times \{ \dot{\vec{r'}} \}_{SNI}$ representa a la llamada fuerza de **Coriolis**; esta es una fuerza perpendicular al eje de rotación y proporcional a la velocidad de la partícula en  el sistema no inercial, tiende a desviar a la partícula de su movimiento.
# - $- m\{\dot{\vec{\omega}} \}_{SNI} \times \vec{r'}$ se llama azimutal o transversal , nótese que $\{\vec{\dot{\omega}}\}_{SNI} = \vec{\dot{\omega}}$, esta fuerza sólo existe cuando hay aceleración angular y es transversal al eje de rotación.
# - $- m\vec{\omega} \times (\vec{\omega} \times \vec{r'})$ es la fuerza centrífuga que apunta siempre hacia afuera del eje de rotación y perpendicular a éste.

# %% [markdown]
# ### 2. Ecuación del Péndulo de Foucault

# %% [markdown]
# ![diagrama](Diagrama1.png)
#
# Se tiene que en la figura el vector $\vec{\Omega}$ representa la velocidad angular para lugares de la tierra con latitud $\lambda$, tal vector esta expresado como:
#
# $$\vec{\Omega} = [-\Omega\cos{(\lambda)},0,\Omega\sin{(\lambda)}]$$
#
# Donde la cantidad $\Omega$ es la velocidad angular de la Tierra que equivale a $7,292 \times 10^{-5}rad\ s^{-1}$, tambien tenemos la posición de la masa para un observador que se encuentra anclado al sistema $XYZ$ esta dada por el vector:
#
# $$\vec{r} = [\ell\sin{(\theta)},0,2\ell\sin^2{(\theta / 2})]$$
#
# Observamos que este vector solo esta en el plano $XZ$ debido a que no se ha considerado la rotación de la tierra por consiguiente es necesario tomar en cuenta la velocidad angular terrestre para obtener una posición más acertada de la masa en $XYZ$ al considerar la rotación.

# %% [markdown]
# Antes de encontrar tal vector denotemos a las componentes de la velocidad angular $\vec{\Omega}$ como:
#
# $$\Omega_x = -\Omega cos(\lambda)$$
#
# $$\Omega_y = 0$$
#
# $$\Omega_z = \Omega \sin{(\lambda)}$$
#
# Ya una vez hecho esto, observamos que la velocidad que afecta al movimiento del péndulo a moverse en e

# %%
using PyCall
using PyPlot

@pyimport matplotlib.animation as anim
# Out:
# INFO: Loading help data...

# %%
using SymPy

# %% [markdown]
# $$L= \frac{1}{2} m (\dot{x}^2 + \dot{y}^2) + m \beta (\dot{y}x -\dot{x}y ) - \frac{1}{2}m \omega _0 ^2 (x^2 + y^2)$$
#
# $$\beta = \Omega cos \alpha$$
# $$ \omega _0 = \sqrt{\frac{g}{\ell}}$$
#
# $\Omega$ Es la velocidad angular de la Tierra y $\alpha$ es el ángulo entre el eje $z$ del péndulo y el eje de rotación de la Tierra.

# %%
m, Ω, g, ℓ,α,t = sym"m,\Omega,g,\ell,\alpha,t"
β  = Ω*cos(α)
x  = SymFunction("x")
y  = SymFunction("y")
ω₀ = sqrt(g/ℓ)
# Out:
#     ______
#    /  g
#   /  ----
# \/   \ell

# %%
T = 1//2 *m*(diff(x(t),t)^2 + diff(y(t),t)^2) + m*β*(diff(y(t),t)*x(t) - diff(x(t),t)*y(t))

ẋ = SymFunction("\\dot{x}")
ẏ = SymFunction("\\dot{y}")

T = subs(T,diff(x(t),t),ẋ(t))
T = subs(T,diff(y(t),t),ẏ(t))
Eq(sym"T",T)
# Out:
#                                                                   /       2
#                                                                 m*\\dot{x} (t)
# T = \Omega*m*(-\dot{x}(t)*y(t) + \dot{y}(t)*x(t))*cos(\alpha) + --------------
#
#
#           2   \
#  + \dot{y} (t)/
# ---------------
# 2

# %%
V = 1//2*m*ω₀^2 * (x(t)^2 + y(t)^2)
Eq(sym"V",V)
# Out:
#         / 2       2   \
#     g*m*\x (t) + y (t)/
# V = -------------------
#            2*\ell

# %%
L = T-V
Eq(sym"L",L)
# Out:
#                                                                   /       2
#                                                                 m*\\dot{x} (t)
# L = \Omega*m*(-\dot{x}(t)*y(t) + \dot{y}(t)*x(t))*cos(\alpha) + --------------
#
#
#           2   \       / 2       2   \
#  + \dot{y} (t)/   g*m*\x (t) + y (t)/
# --------------- - -------------------
# 2                        2*\ell

# %% [markdown]
# Recordando las ecuaciones de Euler-Lagrange.
#
# $$\frac{d}{dt} \frac{\partial L}{\partial \dot{q}} - \frac{\partial L}{\partial q} = 0$$

# %%
Fx = diff(L,x(t))
Fy = diff(L,y(t))
Px = diff(L,ẋ(t))
Py = diff(L,ẏ(t))

Eq₁ = diff(Px,t) - Fx
Eq₂ = diff(Py,t) - Fy

ẍ = SymFunction("\\ddot{x}")
ÿ = SymFunction("\\ddot{y}")

Eq₁ = subs(Eq₁, diff(x(t),t,1), ẋ(t))
Eq₁ = subs(Eq₁, diff(y(t),t,1), ẏ(t))
Eq₂ = subs(Eq₂, diff(x(t),t,1), ẋ(t))
Eq₂ = subs(Eq₂, diff(y(t),t,1), ẏ(t))

Eq₁ = subs(Eq₁, diff(ẋ(t),t,1), ẍ(t))
Eq₁ = subs(Eq₁, diff(ẏ(t),t,1), ÿ(t))
Eq₂ = subs(Eq₂, diff(ẋ(t),t,1), ẍ(t))
Eq₂ = subs(Eq₂, diff(ẏ(t),t,1), ÿ(t))

Eq₁ = Eq₁ |> simplify
Eq₂ = Eq₂ |> simplify;

# %%
(soly, solx) = solve([Eq₁, Eq₂],[ẍ(t), ÿ(t)])
# Out:
# Dict{Any,Any} with 2 entries:
#   "\\ddot{x}(t)" =>                                   g*x(t)…
#   "\\ddot{y}(t)" =>                                    g*y(t)…

# %%
soly = soly[2]
solx = solx[2];

# %%
Eq(ẍ(t), solx)
# Out:
#                                                  g*y(t)
# \ddot{x}(t) = -2*\Omega*\dot{x}(t)*cos(\alpha) - ------
#                                                   \ell

# %%
Eq(ÿ(t), soly)
# Out:
#                                                 g*x(t)
# \ddot{y}(t) = 2*\Omega*\dot{y}(t)*cos(\alpha) - ------
#                                                  \ell

# %%
function sympy_to_julia(x::Sym)
    expr = PyCall.pyeval("str(x)", x=x.x)
    expr = replace(expr, "**", "^")
    expr = replace(expr, "\\dot{y}", "ẏ")
    expr = replace(expr, "\\Omega", "Ω")
    expr = replace(expr, "\g", "g")
    expr = replace(expr, "\\alpha", "α")
    expr = replace(expr, "\\ell", "ℓ")
    expr = replace(expr, "\\dot{x}", "ẋ")
    expr = replace(expr, "\\theta", "θ")
    expr = replace(expr, "(t)","");
end
# Out:
# sympy_to_julia (generic function with 1 method)

# %%
sympy_to_julia(solx)
# Out:
# "-2*Ω*ẋ*cos(α) - g*y/ℓ"

# %%
sympy_to_julia(soly)
# Out:
# "2*Ω*ẏ*cos(α) - g*x/ℓ"

# %%
Ω = 7e-5
g = 9.89
ℓ = 20
α = pi/120

fy(ẋ,ẏ,x,y) = -2*Ω*ẋ*cos(α) - g*y/ℓ
fx(ẋ,ẏ,x,y) = 2*Ω*ẏ*cos(α) - g*x/ℓ
# Out:
# fx (generic function with 1 method)

# %%
function euler_cromer(q0,v0,t0,tf,h,f_q,f_v)
    tf=tf
    q = Vector{Float32}[]
    v = Vector{Float32}[]
    t = Float32[]
    for ti in t0:h:tf
        v_nueva = v0 + h*f_v(q0,v0,ti)
        q_nueva = q0 + h*f_q(q0,v_nueva,ti)
        q0 = q_nueva
        v0 = v_nueva
        push!(t,ti)
        push!(q,q0)
        push!(v,v0)
    end
    t,hcat(q...)',hcat(v...)'
end
# Out:
# euler_cromer (generic function with 1 method)

# %%
12*60*60
# Out:
# 43200

# %%
fv(r₀,v,t) = [fx(v[1],v[2],r₀[1],r₀[2]),fy(v[1],v[2],r₀[1],r₀[2])]
fr(r₀,v,t) = v



t,q,v=euler_cromer([5.0,0.0],[0.0,0.0],0.0,43200,1e-2,fr,fv)

plot(q[:,1],q[:,2])
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x111f76dd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x10c6915d0>

# %%
function trayectoria(q)
    n = length(q)
    Q = Vector{Float32}[q]
    for i in 1:(n-1)
        q₁ = q[1:(n-i)]
        push!(Q,q₁)
    end
    reverse(Q)
end
# Out:
# trayectoria (generic function with 1 method)

# %%
fig = figure()
ax = plt.axes(xlim=(-15, 15), ylim=(-15, 15))

global line1 = ax[:plot]([], [], "ko", lw=2)[1]
global line2 = ax[:plot]([], [], "r", lw=1)[1]

# Inicialización
function init()
    global line1
    global line2

    line1[:set_data]([], [])
    line2[:set_data]([], [])

    return ([line1, line2],None)
end

function animate(i)
    global line1
    # i+1 para que i=0 sea x[1]
    line1[:set_data]([q[1:5000,1][i+1]],[q[1:5000,2][i+1]])
    line2[:set_data](Q₁[1:5000][i+1],Q₂[1:5000][i+1])
    return ([line1, line2],None)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10c6bdbd0>)
# animate (generic function with 1 method)

# %%
myanim = anim.FuncAnimation(fig, animate, init_func=init, frames=length(Q₁[1:5000]), interval=20, blit=true);

myanim[:save]("pendulo_foucault_xy.mp4", extra_args=["-vcodec", "libx264"])

display("text/html", string("""<video autoplay controls><source src="data:video/mp4;base64,""",
base64(open(readbytes,"pendulo_foucault_xy.mp4")),"""" type="video/mp4"></video>"""))
# Out:
# Q₁ not defined
# while loading In[23], in expression starting on line 1

# %%
z = [sqrt(20^2 - q[1:5000,1][i]^2 - q[1:5000,2][i]^2) for i in 1:5000]
    trayectoria_z = trayectoria(z);

# %%
fig = plt.figure()
ax = subplot(111, projection="3d", xlim=(-15, 15), ylim=(-15, 15), zlim=(-25,1))

global line1 = ax[:plot]([], [], "ro", lw=2)[1]
global line2 = ax[:plot]([], [], [], "b")[1]
global line3 = ax[:plot]([], [], [], "ko", lw=2)[1]
global line4 = ax[:plot]([], [], [], "k")[1]

# Inicialización
function init()
    global line1
    global line2
    global line3
    global line4

    line1[:set_data]([], [])
    line1[:set_3d_properties]([])
    
    line2[:set_data]([], [])
    line2[:set_3d_properties]([])
    
    line3[:set_data]([], [])
    line3[:set_3d_properties]([])
    
    line4[:set_data]([], [])
    line4[:set_3d_properties]([])


    return ([line1, line2, line3, line4],None)
end

function animate(i)
    global line1
    global line2
    global line3
    global line4
    
    # i+1 para que i=0 sea x[1]
    
    line1[:set_data]([q[1:5000,1][i+1]],[q[1:5000,2][i+1]])
    line1[:set_3d_properties](-z[i+1])
    
    line2[:set_data](Q₁[1:5000][i+1],Q₂[1:5000][i+1])
    line2[:set_3d_properties](-trayectoria_z[i+1])
    
    line3[:set_data](0,0)
    line3[:set_3d_properties](0)
    
    line4[:set_data]([0, q[1:5000,1][i+1]],[0, q[1:5000,2][i+1]])
    line4[:set_3d_properties]([0,-z[i+1]])
    
    return ([line1,line2,line3,line4],None)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x111f33850>)
# animate (generic function with 1 method)

# %%
myanim = anim.FuncAnimation(fig, animate, init_func=init, frames=length(Q₁[1:5000]), interval=5, blit=true);

myanim[:save]("pendulo_foucault4.mp4", extra_args=["-vcodec", "libx264"])

display("text/html", string("""<video autoplay controls><source src="data:video/mp4;base64,""",
base64(open(readbytes,"pendulo_foucault4.mp4")),"""" type="video/mp4"></video>"""))
# Out:
# Q₁ not defined
# while loading In[26], in expression starting on line 1

# %%
a = 20/10
# Out:
# 2.0

# %%
a == int(a)
# Out:
# true

# %%
function reduccion(q,n)
    Q = [q[1]]
    for i in 1:length(q)
        a = i/n
        if a == int(a)
            push!(Q,q[i])
        end
    end
    Q
end
# Out:
# reduccion (generic function with 1 method)

# %%
length(q[:,1])
# Out:
# 4320001

# %%
X = reduccion(q[:,1],1000)
Y = reduccion(q[:,2],1000)
T₁ = trayectoria(X)
T₂ = trayectoria(Y)
length(X)
# Out:
# 4321

# %%
z = [sqrt(20^2 - X[i]^2 - Y[i]^2) for i in 1:length(X)]
trayectoria_z = trayectoria(z);

# %%
fig = plt.figure()
ax = subplot(111, projection="3d", xlim=(-12.5, 12.5), ylim=(-12.5, 12.5), zlim=(-25,1))

global line1 = ax[:plot]([], [], "mo", lw=2)[1]
global line2 = ax[:plot]([], [], [], "m")[1]
global line3 = ax[:plot]([], [], [], "go", lw=2)[1]
global line4 = ax[:plot]([], [], [], "g")[1]

# Inicialización
function init()
    global line1
    global line2
    global line3
    global line4

    line1[:set_data]([], [])
    line1[:set_3d_properties]([])
    
    line2[:set_data]([], [])
    line2[:set_3d_properties]([])
    
    line3[:set_data]([], [])
    line3[:set_3d_properties]([])
    
    line4[:set_data]([], [])
    line4[:set_3d_properties]([])


    return ([line1, line2, line3, line4],None)
end

function animate(i)
    global line1
    global line2
    global line3
    global line4
    
    # i+1 para que i=0 sea x[1]
    
    line1[:set_data]([X[i+1]],[Y[i+1]])
    line1[:set_3d_properties](-z[i+1])
    
    line2[:set_data](T₁[i+1],T₂[i+1])
    line2[:set_3d_properties](-trayectoria_z[i+1])
    
    line3[:set_data](0,0)
    line3[:set_3d_properties](0)
    
    line4[:set_data]([0, X[i+1]],[0, Y[i+1]])
    line4[:set_3d_properties]([0,-z[i+1]])
    
    return ([line1,line2,line3,line4],None)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1121fe210>)
# animate (generic function with 1 method)

# %%
myanim = anim.FuncAnimation(fig, animate, init_func=init, frames=length(X), interval=20, blit=true);

myanim[:save]("pendulo_foucault4.mp4", extra_args=["-vcodec", "libx264"])

display("text/html", string("""<video autoplay controls><source src="data:video/mp4;base64,""",base64(open(readbytes,"pendulo_foucault4.mp4")),"""" type="video/mp4"></video>"""))
# Out:
# <video autoplay controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %%
# Out:
# Warning: imported binding for transpose overwritten in module __anon__
